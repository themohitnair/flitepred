# %%
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
import numpy as np 
from sklearn.metrics import classification_report, roc_auc_score, confusion_matrix
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier

# %%
df = pd.read_csv("dataset/processed/jfk_optimized.csv")
df.head()
# Out:
#    year  scheduled_elapsed_time        label   dep_sin   dep_cos  \
# 0  2014                   375.0  not_delayed  0.965926 -0.258819
# 1  2014                   385.0      delayed  0.965926 -0.258819
# 2  2014                   385.0      delayed  0.707107 -0.707107
# 3  2014                   389.0      delayed  0.707107 -0.707107
# 4  2014                   374.0  not_delayed  0.639439 -0.768842
#
#    is_holiday_or_weekend  month_1  month_2  month_3  month_4  ...  \
# 0                      1     True    False    False    False  ...
# 1                      1     True    False    False    False  ...
# 2                      1     True    False    False    False  ...
# 3                      1     True    False    False    False  ...
# 4                      1     True    False    False    False  ...
#
#    day_of_week_5  day_of_week_6  day_of_week_7  carrier_AA  carrier_B6  \
# 0          False          False          False       False        True
# 1          False          False          False       False       False
# 2          False          False          False        True       False
# 3          False          False          False       False       False
# 4          False          False          False       False        True
#
#    carrier_DL  departure_bin_night  departure_bin_morning  \
# 0       False                False                   True
# 1        True                False                   True
# 2       False                False                   True
# 3        True                False                   True
# 4       False                False                   True
#
#    departure_bin_afternoon  departure_bin_evening
# 0                    False                  False
# 1                    False                  False
# 2                    False                  False
# 3                    False                  False
# 4                    False                  False
#
# [5 rows x 32 columns]

# %%
df["label"] = df["label"].map({"not_delayed": 0, "delayed": 1})

df_train = df[df["year"].between(2014, 2019)]
df_val = df[df["year"] == 2019]
df_test = df[df["year"].between(2022, 2024)]

# %%
print("Train size:", len(df_train))
print("Val size:  ", len(df_val))
print("Test size: ", len(df_test))
# Out:
# Train size: 60625
# Val size:   10930
# Test size:  29230

# %%
print("Train class distribution:\n", df_train['label'].value_counts(normalize=True))
print("Val class distribution:\n", df_val['label'].value_counts(normalize=True))
print("Test class distribution:\n", df_test['label'].value_counts(normalize=True))
# Out:
# Train class distribution:
#  label
# 0    0.675052
# 1    0.324948
# Name: proportion, dtype: float64
# Val class distribution:
#  label
# 0    0.726167
# 1    0.273833
# Name: proportion, dtype: float64
# Test class distribution:
#  label
# 0    0.652275
# 1    0.347725
# Name: proportion, dtype: float64

# %%
xgb_model = XGBClassifier(
    n_estimators=300,
    max_depth=6,
    learning_rate=0.05,
    scale_pos_weight=2.5,
    subsample=0.8,
    colsample_bytree=0.8,
    eval_metric='logloss',
    use_label_encoder=False,
    early_stopping_rounds=30,
    verbose=True
)

# %%
X = df_train.drop(columns=["label"])
y = df_train["label"]

X_val = df_val.drop(columns=["label"])
y_val = df_val["label"]

X_test = df_test.drop(columns=["label"])
y_test = df_test["label"]

# %%
model.fit(
    X, y,
    eval_set=[(X_val, y_val)],    
)
# Out:
# [0]	validation_0-logloss:0.73160
# [1]	validation_0-logloss:0.72465
# [2]	validation_0-logloss:0.71858
# [3]	validation_0-logloss:0.71249
# [4]	validation_0-logloss:0.70710
# [5]	validation_0-logloss:0.70225
# [6]	validation_0-logloss:0.69776
# [7]	validation_0-logloss:0.69318
# [8]	validation_0-logloss:0.68910
# [9]	validation_0-logloss:0.68538
# [10]	validation_0-logloss:0.68190
# [11]	validation_0-logloss:0.68018
# [12]	validation_0-logloss:0.67814
# [13]	validation_0-logloss:0.67501
# [14]	validation_0-logloss:0.67265
# [15]	validation_0-logloss:0.66955
# [16]	validation_0-logloss:0.66736
# [17]	validation_0-logloss:0.66472
# [18]	validation_0-logloss:0.66224
# [19]	validation_0-logloss:0.66000
# [20]	validation_0-logloss:0.65800
# [21]	validation_0-logloss:0.65623
# [22]	validation_0-logloss:0.65450
# [23]	validation_0-logloss:0.65300
# [24]	validation_0-logloss:0.65159
# [25]	validation_0-logloss:0.65095
# [26]	validation_0-logloss:0.65031
# [27]	validation_0-logloss:0.64967
# [28]	validation_0-logloss:0.64821
# [29]	validation_0-logloss:0.64695
# [30]	validation_0-logloss:0.64652
# /home/themohitnair/Skywalker/flitepred/.venv/lib/python3.10/site-packages/xgboost/callback.py:386: UserWarning: [20:40:43] WARNING: /workspace/src/learner.cc:738:
# Parameters: { "use_label_encoder", "verbose" } are not used.
#
#   self.starting_round = model.num_boosted_rounds()
# [31]	validation_0-logloss:0.64615
# [32]	validation_0-logloss:0.64471
# [33]	validation_0-logloss:0.64301
# [34]	validation_0-logloss:0.64179
# [35]	validation_0-logloss:0.64129
# [36]	validation_0-logloss:0.64076
# [37]	validation_0-logloss:0.63967
# [38]	validation_0-logloss:0.63938
# [39]	validation_0-logloss:0.63842
# [40]	validation_0-logloss:0.63731
# [41]	validation_0-logloss:0.63713
# [42]	validation_0-logloss:0.63646
# [43]	validation_0-logloss:0.63616
# [44]	validation_0-logloss:0.63508
# [45]	validation_0-logloss:0.63387
# [46]	validation_0-logloss:0.63301
# [47]	validation_0-logloss:0.63248
# [48]	validation_0-logloss:0.63164
# [49]	validation_0-logloss:0.63126
# [50]	validation_0-logloss:0.63048
# [51]	validation_0-logloss:0.62994
# [52]	validation_0-logloss:0.62901
# [53]	validation_0-logloss:0.62844
# [54]	validation_0-logloss:0.62797
# [55]	validation_0-logloss:0.62765
# [56]	validation_0-logloss:0.62709
# [57]	validation_0-logloss:0.62621
# [58]	validation_0-logloss:0.62535
# [59]	validation_0-logloss:0.62460
# [60]	validation_0-logloss:0.62452
# [61]	validation_0-logloss:0.62419
# [62]	validation_0-logloss:0.62393
# [63]	validation_0-logloss:0.62324
# [64]	validation_0-logloss:0.62288
# [65]	validation_0-logloss:0.62232
# [66]	validation_0-logloss:0.62189
# [67]	validation_0-logloss:0.62135
# [68]	validation_0-logloss:0.62094
# [69]	validation_0-logloss:0.62062
# [70]	validation_0-logloss:0.62022
# [71]	validation_0-logloss:0.62012
# [72]	validation_0-logloss:0.61975
# [73]	validation_0-logloss:0.61930
# [74]	validation_0-logloss:0.61903
# [75]	validation_0-logloss:0.61874
# [76]	validation_0-logloss:0.61834
# [77]	validation_0-logloss:0.61819
# [78]	validation_0-logloss:0.61805
# [79]	validation_0-logloss:0.61798
# [80]	validation_0-logloss:0.61759
# [81]	validation_0-logloss:0.61707
# [82]	validation_0-logloss:0.61692
# [83]	validation_0-logloss:0.61618
# [84]	validation_0-logloss:0.61577
# [85]	validation_0-logloss:0.61549
# [86]	validation_0-logloss:0.61531
# [87]	validation_0-logloss:0.61513
# [88]	validation_0-logloss:0.61509
# [89]	validation_0-logloss:0.61497
# [90]	validation_0-logloss:0.61472
# [91]	validation_0-logloss:0.61432
# [92]	validation_0-logloss:0.61396
# [93]	validation_0-logloss:0.61371
# [94]	validation_0-logloss:0.61302
# [95]	validation_0-logloss:0.61296
# [96]	validation_0-logloss:0.61293
# [97]	validation_0-logloss:0.61273
# [98]	validation_0-logloss:0.61249
# [99]	validation_0-logloss:0.61245
# [100]	validation_0-logloss:0.61239
# [101]	validation_0-logloss:0.61212
# [102]	validation_0-logloss:0.61196
# [103]	validation_0-logloss:0.61186
# [104]	validation_0-logloss:0.61182
# [105]	validation_0-logloss:0.61169
# [106]	validation_0-logloss:0.61120
# [107]	validation_0-logloss:0.61088
# [108]	validation_0-logloss:0.61049
# [109]	validation_0-logloss:0.61031
# [110]	validation_0-logloss:0.61019
# [111]	validation_0-logloss:0.60998
# [112]	validation_0-logloss:0.60999
# [113]	validation_0-logloss:0.60973
# [114]	validation_0-logloss:0.60944
# [115]	validation_0-logloss:0.60953
# [116]	validation_0-logloss:0.60928
# [117]	validation_0-logloss:0.60929
# [118]	validation_0-logloss:0.60919
# [119]	validation_0-logloss:0.60890
# [120]	validation_0-logloss:0.60871
# [121]	validation_0-logloss:0.60835
# [122]	validation_0-logloss:0.60790
# [123]	validation_0-logloss:0.60764
# [124]	validation_0-logloss:0.60749
# [125]	validation_0-logloss:0.60747
# [126]	validation_0-logloss:0.60738
# [127]	validation_0-logloss:0.60721
# [128]	validation_0-logloss:0.60718
# [129]	validation_0-logloss:0.60703
# [130]	validation_0-logloss:0.60666
# [131]	validation_0-logloss:0.60663
# [132]	validation_0-logloss:0.60639
# [133]	validation_0-logloss:0.60602
# [134]	validation_0-logloss:0.60598
# [135]	validation_0-logloss:0.60563
# [136]	validation_0-logloss:0.60537
# [137]	validation_0-logloss:0.60519
# [138]	validation_0-logloss:0.60507
# [139]	validation_0-logloss:0.60513
# [140]	validation_0-logloss:0.60456
# [141]	validation_0-logloss:0.60455
# [142]	validation_0-logloss:0.60451
# [143]	validation_0-logloss:0.60409
# [144]	validation_0-logloss:0.60330
# [145]	validation_0-logloss:0.60329
# [146]	validation_0-logloss:0.60294
# [147]	validation_0-logloss:0.60295
# [148]	validation_0-logloss:0.60287
# [149]	validation_0-logloss:0.60284
# [150]	validation_0-logloss:0.60272
# [151]	validation_0-logloss:0.60264
# [152]	validation_0-logloss:0.60256
# [153]	validation_0-logloss:0.60235
# [154]	validation_0-logloss:0.60225
# [155]	validation_0-logloss:0.60209
# [156]	validation_0-logloss:0.60211
# [157]	validation_0-logloss:0.60208
# [158]	validation_0-logloss:0.60213
# [159]	validation_0-logloss:0.60221
# [160]	validation_0-logloss:0.60200
# [161]	validation_0-logloss:0.60188
# [162]	validation_0-logloss:0.60194
# [163]	validation_0-logloss:0.60183
# [164]	validation_0-logloss:0.60182
# [165]	validation_0-logloss:0.60183
# [166]	validation_0-logloss:0.60168
# [167]	validation_0-logloss:0.60153
# [168]	validation_0-logloss:0.60151
# [169]	validation_0-logloss:0.60132
# [170]	validation_0-logloss:0.60116
# [171]	validation_0-logloss:0.60114
# [172]	validation_0-logloss:0.60115
# [173]	validation_0-logloss:0.60112
# [174]	validation_0-logloss:0.60064
# [175]	validation_0-logloss:0.60067
# [176]	validation_0-logloss:0.60065
# [177]	validation_0-logloss:0.60047
# [178]	validation_0-logloss:0.60035
# [179]	validation_0-logloss:0.60027
# [180]	validation_0-logloss:0.59996
# [181]	validation_0-logloss:0.59995
# [182]	validation_0-logloss:0.59990
# [183]	validation_0-logloss:0.59985
# [184]	validation_0-logloss:0.59986
# [185]	validation_0-logloss:0.59963
# [186]	validation_0-logloss:0.59960
# [187]	validation_0-logloss:0.59925
# [188]	validation_0-logloss:0.59913
# [189]	validation_0-logloss:0.59886
# [190]	validation_0-logloss:0.59876
# [191]	validation_0-logloss:0.59872
# [192]	validation_0-logloss:0.59834
# [193]	validation_0-logloss:0.59814
# [194]	validation_0-logloss:0.59806
# [195]	validation_0-logloss:0.59795
# [196]	validation_0-logloss:0.59793
# [197]	validation_0-logloss:0.59779
# [198]	validation_0-logloss:0.59770
# [199]	validation_0-logloss:0.59763
# [200]	validation_0-logloss:0.59758
# [201]	validation_0-logloss:0.59744
# [202]	validation_0-logloss:0.59722
# [203]	validation_0-logloss:0.59725
# [204]	validation_0-logloss:0.59711
# [205]	validation_0-logloss:0.59687
# [206]	validation_0-logloss:0.59679
# [207]	validation_0-logloss:0.59656
# [208]	validation_0-logloss:0.59641
# [209]	validation_0-logloss:0.59627
# [210]	validation_0-logloss:0.59629
# [211]	validation_0-logloss:0.59628
# [212]	validation_0-logloss:0.59619
# [213]	validation_0-logloss:0.59617
# [214]	validation_0-logloss:0.59606
# [215]	validation_0-logloss:0.59593
# [216]	validation_0-logloss:0.59588
# [217]	validation_0-logloss:0.59570
# [218]	validation_0-logloss:0.59564
# [219]	validation_0-logloss:0.59553
# [220]	validation_0-logloss:0.59542
# [221]	validation_0-logloss:0.59512
# [222]	validation_0-logloss:0.59502
# [223]	validation_0-logloss:0.59486
# [224]	validation_0-logloss:0.59478
# [225]	validation_0-logloss:0.59462
# [226]	validation_0-logloss:0.59459
# [227]	validation_0-logloss:0.59429
# [228]	validation_0-logloss:0.59411
# [229]	validation_0-logloss:0.59405
# [230]	validation_0-logloss:0.59377
# [231]	validation_0-logloss:0.59356
# [232]	validation_0-logloss:0.59339
# [233]	validation_0-logloss:0.59322
# [234]	validation_0-logloss:0.59317
# [235]	validation_0-logloss:0.59314
# [236]	validation_0-logloss:0.59303
# [237]	validation_0-logloss:0.59302
# [238]	validation_0-logloss:0.59292
# [239]	validation_0-logloss:0.59278
# [240]	validation_0-logloss:0.59257
# [241]	validation_0-logloss:0.59269
# [242]	validation_0-logloss:0.59262
# [243]	validation_0-logloss:0.59246
# [244]	validation_0-logloss:0.59248
# [245]	validation_0-logloss:0.59222
# [246]	validation_0-logloss:0.59212
# [247]	validation_0-logloss:0.59205
# [248]	validation_0-logloss:0.59195
# [249]	validation_0-logloss:0.59194
# [250]	validation_0-logloss:0.59192
# [251]	validation_0-logloss:0.59190
# [252]	validation_0-logloss:0.59188
# [253]	validation_0-logloss:0.59164
# [254]	validation_0-logloss:0.59155
# [255]	validation_0-logloss:0.59138
# [256]	validation_0-logloss:0.59130
# [257]	validation_0-logloss:0.59124
# [258]	validation_0-logloss:0.59130
# [259]	validation_0-logloss:0.59114
# [260]	validation_0-logloss:0.59107
# [261]	validation_0-logloss:0.59097
# [262]	validation_0-logloss:0.59088
# [263]	validation_0-logloss:0.59079
# [264]	validation_0-logloss:0.59071
# [265]	validation_0-logloss:0.59056
# [266]	validation_0-logloss:0.59042
# [267]	validation_0-logloss:0.59036
# [268]	validation_0-logloss:0.59023
# [269]	validation_0-logloss:0.59016
# [270]	validation_0-logloss:0.59001
# [271]	validation_0-logloss:0.58984
# [272]	validation_0-logloss:0.58985
# [273]	validation_0-logloss:0.58993
# [274]	validation_0-logloss:0.58995
# [275]	validation_0-logloss:0.58998
# [276]	validation_0-logloss:0.59000
# [277]	validation_0-logloss:0.58992
# [278]	validation_0-logloss:0.58963
# [279]	validation_0-logloss:0.58948
# [280]	validation_0-logloss:0.58933
# [281]	validation_0-logloss:0.58929
# [282]	validation_0-logloss:0.58925
# [283]	validation_0-logloss:0.58918
# [284]	validation_0-logloss:0.58914
# [285]	validation_0-logloss:0.58889
# [286]	validation_0-logloss:0.58890
# [287]	validation_0-logloss:0.58883
# [288]	validation_0-logloss:0.58873
# [289]	validation_0-logloss:0.58858
# [290]	validation_0-logloss:0.58848
# [291]	validation_0-logloss:0.58821
# [292]	validation_0-logloss:0.58819
# [293]	validation_0-logloss:0.58810
# [294]	validation_0-logloss:0.58791
# [295]	validation_0-logloss:0.58777
# [296]	validation_0-logloss:0.58778
# [297]	validation_0-logloss:0.58790
# [298]	validation_0-logloss:0.58783
# [299]	validation_0-logloss:0.58757
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.8, device=None, early_stopping_rounds=30,
#               enable_categorical=False, eval_metric='logloss',
#               feature_types=None, feature_weights=None, gamma=None,
#               grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.05, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=6, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=300, n_jobs=None,
#               num_parallel_tree=None, ...)

# %%
y_val_pred = model.predict(X_val)
y_val_proba = model.predict_proba(X_val)[:, 1]

print(classification_report(y_val, y_val_pred))
print("Validation ROC AUC:", roc_auc_score(y_val, y_val_proba))
print("Confusion Matrix:\n", confusion_matrix(y_val, y_val_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.69      0.76      7937
#            1       0.45      0.65      0.53      2993
#
#     accuracy                           0.68     10930
#    macro avg       0.64      0.67      0.65     10930
# weighted avg       0.73      0.68      0.70     10930
#
# Validation ROC AUC: 0.7459230077016882
# Confusion Matrix:
#  [[5515 2422]
#  [1033 1960]]
